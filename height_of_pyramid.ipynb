# %% [markdown]
# ![image.png](attachment:image.png)

# %%
blocks: int = int(input("Enter the number of blocks: "))

height: int = 0
total: int = 0
while blocks <= 999999999999:
    height += 1
    total += height
    if total >= blocks:
        break


print("The height of the pyramid:", height)
# Out:
# The height of the pyramid: 3
